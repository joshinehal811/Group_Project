# %%
import requests
import pandas as pd
import time
from io import StringIO  # Import StringIO from io
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from imblearn.combine import SMOTEENN
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
#
#
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.

# %%
# Base URL for the API
base_url = "https://data.austintexas.gov/resource/9t4d-g238.csv"

# Parameters for pagination
limit = 1000
offset = 0
all_data = []

# Function to get data with offset
def get_data(offset):
    params = {
        "$limit": limit,
        "$offset": offset
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        print(f"Data retrieved with offset: {offset}")
        # Use StringIO from io module
        return pd.read_csv(StringIO(response.text))
    else:
        print(f"Failed to retrieve data for offset: {offset}")
        return pd.DataFrame()

# Loop through the dataset using pagination
while True:
    # Get data for the current offset
    df = get_data(offset)

    # Break if no more data is returned
    if df.empty:
        print("No more data to retrieve.")
        break

    # Append the data to the list
    all_data.append(df)

    # Increment the offset for the next request
    offset += limit

    # Sleep to avoid hitting the API rate limit
    time.sleep(1)

# Combine all pages into a single DataFrame
final_df = pd.concat(all_data, ignore_index=True)

# Display the combined DataFrame
print(f"\nFinal DataFrame Shape: {final_df.shape}")
print(final_df.head())
# Out:
# Data retrieved with offset: 0
# Data retrieved with offset: 1000
# Data retrieved with offset: 2000
# Data retrieved with offset: 3000
# Data retrieved with offset: 4000
# Data retrieved with offset: 5000
# Data retrieved with offset: 6000
# Data retrieved with offset: 7000
# Data retrieved with offset: 8000
# Data retrieved with offset: 9000
# Data retrieved with offset: 10000
# Data retrieved with offset: 11000
# Data retrieved with offset: 12000
# Data retrieved with offset: 13000
# Data retrieved with offset: 14000
# Data retrieved with offset: 15000
# Data retrieved with offset: 16000
# Data retrieved with offset: 17000
# Data retrieved with offset: 18000
# Data retrieved with offset: 19000
# Data retrieved with offset: 20000
# Data retrieved with offset: 21000
# Data retrieved with offset: 22000
# Data retrieved with offset: 23000
# Data retrieved with offset: 24000
# Data retrieved with offset: 25000
# Data retrieved with offset: 26000
# Data retrieved with offset: 27000
# Data retrieved with offset: 28000
# Data retrieved with offset: 29000
# Data retrieved with offset: 30000
# Data retrieved with offset: 31000
# Data retrieved with offset: 32000
# Data retrieved with offset: 33000
# Data retrieved with offset: 34000
# Data retrieved with offset: 35000
# Data retrieved with offset: 36000
# Data retrieved with offset: 37000
# Data retrieved with offset: 38000
# Data retrieved with offset: 39000
# Data retrieved with offset: 40000
# Data retrieved with offset: 41000
# Data retrieved with offset: 42000
# Data retrieved with offset: 43000
# Data retrieved with offset: 44000
# Data retrieved with offset: 45000
# Data retrieved with offset: 46000
# Data retrieved with offset: 47000
# Data retrieved with offset: 48000
# Data retrieved with offset: 49000
# Data retrieved with offset: 50000
# Data retrieved with offset: 51000
# Data retrieved with offset: 52000
# Data retrieved with offset: 53000
# Data retrieved with offset: 54000
# Data retrieved with offset: 55000
# Data retrieved with offset: 56000
# Data retrieved with offset: 57000
# Data retrieved with offset: 58000
# Data retrieved with offset: 59000
# Data retrieved with offset: 60000
# Data retrieved with offset: 61000
# Data retrieved with offset: 62000
# Data retrieved with offset: 63000
# Data retrieved with offset: 64000
# Data retrieved with offset: 65000
# Data retrieved with offset: 66000
# Data retrieved with offset: 67000
# Data retrieved with offset: 68000
# Data retrieved with offset: 69000
# Data retrieved with offset: 70000
# Data retrieved with offset: 71000
# Data retrieved with offset: 72000
# Data retrieved with offset: 73000
# Data retrieved with offset: 74000
# Data retrieved with offset: 75000
# Data retrieved with offset: 76000
# Data retrieved with offset: 77000
# Data retrieved with offset: 78000
# Data retrieved with offset: 79000
# Data retrieved with offset: 80000
# Data retrieved with offset: 81000
# Data retrieved with offset: 82000
# Data retrieved with offset: 83000
# Data retrieved with offset: 84000
# Data retrieved with offset: 85000
# Data retrieved with offset: 86000
# Data retrieved with offset: 87000
# Data retrieved with offset: 88000
# Data retrieved with offset: 89000
# Data retrieved with offset: 90000
# Data retrieved with offset: 91000
# Data retrieved with offset: 92000
# Data retrieved with offset: 93000
# Data retrieved with offset: 94000
# Data retrieved with offset: 95000
# Data retrieved with offset: 96000
# Data retrieved with offset: 97000
# Data retrieved with offset: 98000
# Data retrieved with offset: 99000
# Data retrieved with offset: 100000
# Data retrieved with offset: 101000
# Data retrieved with offset: 102000
# Data retrieved with offset: 103000
# Data retrieved with offset: 104000
# Data retrieved with offset: 105000
# Data retrieved with offset: 106000
# Data retrieved with offset: 107000
# Data retrieved with offset: 108000
# Data retrieved with offset: 109000
# Data retrieved with offset: 110000
# Data retrieved with offset: 111000
# Data retrieved with offset: 112000
# Data retrieved with offset: 113000
# Data retrieved with offset: 114000
# Data retrieved with offset: 115000
# Data retrieved with offset: 116000
# Data retrieved with offset: 117000
# Data retrieved with offset: 118000
# Data retrieved with offset: 119000
# Data retrieved with offset: 120000
# Data retrieved with offset: 121000
# Data retrieved with offset: 122000
# Data retrieved with offset: 123000
# Data retrieved with offset: 124000
# Data retrieved with offset: 125000
# Data retrieved with offset: 126000
# Data retrieved with offset: 127000
# Data retrieved with offset: 128000
# Data retrieved with offset: 129000
# Data retrieved with offset: 130000
# Data retrieved with offset: 131000
# Data retrieved with offset: 132000
# Data retrieved with offset: 133000
# Data retrieved with offset: 134000
# Data retrieved with offset: 135000
# Data retrieved with offset: 136000
# Data retrieved with offset: 137000
# Data retrieved with offset: 138000
# Data retrieved with offset: 139000
# Data retrieved with offset: 140000
# Data retrieved with offset: 141000
# Data retrieved with offset: 142000
# Data retrieved with offset: 143000
# Data retrieved with offset: 144000
# Data retrieved with offset: 145000
# Data retrieved with offset: 146000
# Data retrieved with offset: 147000
# Data retrieved with offset: 148000
# Data retrieved with offset: 149000
# Data retrieved with offset: 150000
# Data retrieved with offset: 151000
# Data retrieved with offset: 152000
# Data retrieved with offset: 153000
# Data retrieved with offset: 154000
# Data retrieved with offset: 155000
# Data retrieved with offset: 156000
# Data retrieved with offset: 157000
# Data retrieved with offset: 158000
# Data retrieved with offset: 159000
# Data retrieved with offset: 160000
# Data retrieved with offset: 161000
# Data retrieved with offset: 162000
# Data retrieved with offset: 163000
# Data retrieved with offset: 164000
# Data retrieved with offset: 165000
# Data retrieved with offset: 166000
# Data retrieved with offset: 167000
# Data retrieved with offset: 168000
# Data retrieved with offset: 169000
# Data retrieved with offset: 170000
# Data retrieved with offset: 171000
# Data retrieved with offset: 172000
# No more data to retrieve.
#
# Final DataFrame Shape: (171795, 12)
#   animal_id       name                 datetime                monthyear  \
# 0   A882831  *Hamilton  2023-07-01T18:12:00.000  2023-07-01T18:12:00.000
# 1   A794011      Chunk  2019-05-08T18:20:00.000  2019-05-08T18:20:00.000
# 2   A776359      Gizmo  2018-07-18T16:02:00.000  2018-07-18T16:02:00.000
# 3   A821648        NaN  2020-08-16T11:38:00.000  2020-08-16T11:38:00.000
# 4   A720371      Moose  2016-02-13T17:59:00.000  2016-02-13T17:59:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2023-03-25T00:00:00.000     Adoption             NaN         Cat
# 1  2017-05-02T00:00:00.000    Rto-Adopt             NaN         Cat
# 2  2017-07-12T00:00:00.000     Adoption             NaN         Dog
# 3  2019-08-16T00:00:00.000   Euthanasia             NaN       Other
# 4  2015-10-08T00:00:00.000     Adoption             NaN         Dog
#
#   sex_upon_outcome age_upon_outcome                               breed  \
# 0    Neutered Male         3 months              Domestic Shorthair Mix
# 1    Neutered Male          2 years              Domestic Shorthair Mix
# 2    Neutered Male           1 year             Chihuahua Shorthair Mix
# 3          Unknown           1 year                             Raccoon
# 4    Neutered Male         4 months  Anatol Shepherd/Labrador Retriever
#
#                color
# 0        Black/White
# 1  Brown Tabby/White
# 2        White/Brown
# 3               Gray
# 4               Buff

# %% [markdown]
# # **Data Dictionary for Austin Animal Center Outcomes Dataset**
#
# | Column Name         | Description                                                  | API Field Name      | Data Type           |
# |---------------------|--------------------------------------------------------------|---------------------|---------------------|
# | **Animal ID**       | Unique identifier for each animal                            | `animal_id`         | Text                |
# | **Name**            | Name of the animal (if available)                             | `name`              | Text                |
# | **DateTime**        | Date and time of the outcome event                            | `datetime`          | Floating Timestamp  |
# | **MonthYear**       | Month and year of the outcome event                           | `monthyear`         | Floating Timestamp  |
# | **Date of Birth**   | Date of birth of the animal                                   | `date_of_birth`     | Floating Timestamp  |
# | **Outcome Type**    | General category of outcome (e.g., Adoption, Transfer, Euthanasia) | `outcome_type` | Text                |
# | **Outcome Subtype** | Specific subtype of outcome (e.g., Offsite, Foster)            | `outcome_subtype`   | Text                |
# | **Animal Type**     | Type of animal (e.g., Dog, Cat)                               | `animal_type`       | Text                |
# | **Sex upon Outcome**| Sex and reproductive status upon outcome (e.g., Neutered Male) | `sex_upon_outcome`  | Text                |
# | **Age upon Outcome**| Age of the animal at the time of outcome                      | `age_upon_outcome`  | Text                |
# | **Breed**           | Breed of the animal                                            | `breed`             | Text                |
# | **Color**           | Color description of the animal                               | `color`             | Text                |

# %% [markdown]
# # **EDA and Feature Engineering**

# %%
final_df.head()
# Out:
#   animal_id       name                 datetime                monthyear  \
# 0   A882831  *Hamilton  2023-07-01T18:12:00.000  2023-07-01T18:12:00.000
# 1   A794011      Chunk  2019-05-08T18:20:00.000  2019-05-08T18:20:00.000
# 2   A776359      Gizmo  2018-07-18T16:02:00.000  2018-07-18T16:02:00.000
# 3   A821648        NaN  2020-08-16T11:38:00.000  2020-08-16T11:38:00.000
# 4   A720371      Moose  2016-02-13T17:59:00.000  2016-02-13T17:59:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2023-03-25T00:00:00.000     Adoption             NaN         Cat
# 1  2017-05-02T00:00:00.000    Rto-Adopt             NaN         Cat
# 2  2017-07-12T00:00:00.000     Adoption             NaN         Dog
# 3  2019-08-16T00:00:00.000   Euthanasia             NaN       Other
# 4  2015-10-08T00:00:00.000     Adoption             NaN         Dog
#
#   sex_upon_outcome age_upon_outcome                               breed  \
# 0    Neutered Male         3 months              Domestic Shorthair Mix
# 1    Neutered Male          2 years              Domestic Shorthair Mix
# 2    Neutered Male           1 year             Chihuahua Shorthair Mix
# 3          Unknown           1 year                             Raccoon
# 4    Neutered Male         4 months  Anatol Shepherd/Labrador Retriever
#
#                color
# 0        Black/White
# 1  Brown Tabby/White
# 2        White/Brown
# 3               Gray
# 4               Buff

# %%
data = final_df.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171795 entries, 0 to 171794
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   animal_id         171795 non-null  object
#  1   name              122637 non-null  object
#  2   datetime          171795 non-null  object
#  3   monthyear         171795 non-null  object
#  4   date_of_birth     171795 non-null  object
#  5   outcome_type      171753 non-null  object
#  6   outcome_subtype   78709 non-null   object
#  7   animal_type       171795 non-null  object
#  8   sex_upon_outcome  171793 non-null  object
#  9   age_upon_outcome  171789 non-null  object
#  10  breed             171795 non-null  object
#  11  color             171795 non-null  object
# dtypes: object(12)
# memory usage: 15.7+ MB

# %%
data.describe()
# Out:
#        animal_id    name                 datetime                monthyear  \
# count     171795  122637                   171795                   171795
# unique    154441   29543                   143552                   143552
# top      A721033    Luna  2016-04-18T00:00:00.000  2016-04-18T00:00:00.000
# freq          33     748                       39                       39
#
#                   date_of_birth outcome_type outcome_subtype animal_type  \
# count                    171795       171753           78709      171795
# unique                     8605           11              26           5
# top     2016-05-01T00:00:00.000     Adoption         Partner         Dog
# freq                        121        83517           39991       93553
#
#        sex_upon_outcome age_upon_outcome                   breed        color
# count            171793           171789                  171795       171795
# unique                5               55                    2988          659
# top       Neutered Male           1 year  Domestic Shorthair Mix  Black/White
# freq              60242            28453                   34024        17791

# %%
#percentage of duplicate rows
duplicate_rows = data[data.duplicated()]
duplicate_percentage = (len(duplicate_rows) / len(data)) * 100

#percentage of null values for each column
null_percentages = data.isnull().sum() / len(data) * 100

print(f"Percentage of duplicate rows: {duplicate_percentage:.2f}%")
print("\nPercentage of null values per column:")
null_percentages
# Out:
# Percentage of duplicate rows: 0.01%
#
# Percentage of null values per column:
# animal_id            0.000000
# name                28.614337
# datetime             0.000000
# monthyear            0.000000
# date_of_birth        0.000000
# outcome_type         0.024448
# outcome_subtype     54.184348
# animal_type          0.000000
# sex_upon_outcome     0.001164
# age_upon_outcome     0.003493
# breed                0.000000
# color                0.000000
# dtype: float64

# %%
data.isnull().sum()
# Out:
# animal_id               0
# name                49158
# datetime                0
# monthyear               0
# date_of_birth           0
# outcome_type           42
# outcome_subtype     93086
# animal_type             0
# sex_upon_outcome        2
# age_upon_outcome        6
# breed                   0
# color                   0
# dtype: int64

# %%
data['outcome_type'].value_counts()
# Out:
# outcome_type
# Adoption           83517
# Transfer           48193
# Return to Owner    25508
# Euthanasia         10662
# Died                1653
# Rto-Adopt           1226
# Disposal             867
# Missing               92
# Relocate              28
# Stolen                 5
# Lost                   2
# Name: count, dtype: int64

# %%
outcome_counts = data['outcome_type'].value_counts()
outcome_percentages = (outcome_counts / len(data)) * 100
outcome_percentages
# Out:
# outcome_type
# Adoption           48.614337
# Transfer           28.052621
# Return to Owner    14.847929
# Euthanasia          6.206234
# Died                0.962193
# Rto-Adopt           0.713641
# Disposal            0.504671
# Missing             0.053552
# Relocate            0.016298
# Stolen              0.002910
# Lost                0.001164
# Name: count, dtype: float64

# %%
plt.figure(figsize=(10, 6))
bars = sns.barplot(x=outcome_counts.index, y=outcome_counts.values)
plt.xlabel("Outcomes")
plt.ylabel("Counts of Events")
plt.title("Distribution of Outcomes")
plt.xticks(rotation=45, ha='right')

for bar in bars.patches:
    bars.annotate(f'{int(bar.get_height())}',
                   (bar.get_x() + bar.get_width() / 2, bar.get_height()),
                   ha='center', va='bottom',
                   xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
import re

def convert_age_to_days(age_str):
    # Handle negative values
    if pd.isna(age_str) or '-' in age_str:
        return np.nan

    # Extract numerical value and unit
    match = re.match(r"(\d+)\s(\w+)", age_str)
    if match:
        value, unit = int(match.group(1)), match.group(2).lower()

        # Convert to days based on unit
        if 'year' in unit:
            return value * 365
        elif 'month' in unit:
            return value * 30
        elif 'week' in unit:
            return value * 7
        elif 'day' in unit:
            return value
    return np.nan

# %%
data['age_days'] = data['age_upon_outcome'].apply(convert_age_to_days)

#Distribution of Age in Days
print(data['age_days'].describe())
print("Negative or NaN Age Days:", data[data['age_days'] <= 0]['age_days'].count())
# Out:
# count    171780.000000
# mean        723.614751
# std        1022.748279
# min           0.000000
# 25%          60.000000
# 50%         365.000000
# 75%         730.000000
# max       10950.000000
# Name: age_days, dtype: float64
# Negative or NaN Age Days: 268

# %%
data['date_of_birth'] = pd.to_datetime(data['date_of_birth'], errors='coerce')

data['day_of_birth'] = data['date_of_birth'].dt.day
data['month_of_birth'] = data['date_of_birth'].dt.month
data['year_of_birth'] = data['date_of_birth'].dt.year

# %%
data['datetime'] = pd.to_datetime(data['datetime'], errors='coerce')

data['outcome_event_day'] = data['datetime'].dt.day
data['outcome_event_month'] = data['datetime'].dt.month
data['outcome_event_year'] = data['datetime'].dt.year

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171795 entries, 0 to 171794
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   animal_id            171795 non-null  object
#  1   name                 122637 non-null  object
#  2   datetime             171795 non-null  datetime64[ns]
#  3   monthyear            171795 non-null  object
#  4   date_of_birth        171795 non-null  datetime64[ns]
#  5   outcome_type         171753 non-null  object
#  6   outcome_subtype      78709 non-null   object
#  7   animal_type          171795 non-null  object
#  8   sex_upon_outcome     171793 non-null  object
#  9   age_upon_outcome     171789 non-null  object
#  10  breed                171795 non-null  object
#  11  color                171795 non-null  object
#  12  age_days             171780 non-null  float64
#  13  day_of_birth         171795 non-null  int32
#  14  month_of_birth       171795 non-null  int32
#  15  year_of_birth        171795 non-null  int32
#  16  outcome_event_day    171795 non-null  int32
#  17  outcome_event_month  171795 non-null  int32
#  18  outcome_event_year   171795 non-null  int32
# dtypes: datetime64[ns](2), float64(1), int32(6), object(10)
# memory usage: 21.0+ MB

# %%
# Extract Season of Outcome
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'
    else:
        return 'Unknown'

data['outcome_event_season'] = data['outcome_event_month'].apply(get_season)

# %%
def simplify_sex(sex):
    if sex in ['Neutered Male', 'Spayed Female']:
        return 'Fixed'
    elif sex in ['Intact Male', 'Intact Female']:
        return 'Intact'
    else:
        return 'Unknown'

data['reproductive_status'] = final_df['sex_upon_outcome'].apply(simplify_sex)

# %%
# Text Features from Name
data['name_length'] = data['name'].fillna('').apply(len)
data['has_name'] = data['name'].notna().astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171795 entries, 0 to 171794
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   animal_id             171795 non-null  object
#  1   name                  122637 non-null  object
#  2   datetime              171795 non-null  datetime64[ns]
#  3   monthyear             171795 non-null  object
#  4   date_of_birth         171795 non-null  datetime64[ns]
#  5   outcome_type          171753 non-null  object
#  6   outcome_subtype       78709 non-null   object
#  7   animal_type           171795 non-null  object
#  8   sex_upon_outcome      171793 non-null  object
#  9   age_upon_outcome      171789 non-null  object
#  10  breed                 171795 non-null  object
#  11  color                 171795 non-null  object
#  12  age_days              171780 non-null  float64
#  13  day_of_birth          171795 non-null  int32
#  14  month_of_birth        171795 non-null  int32
#  15  year_of_birth         171795 non-null  int32
#  16  outcome_event_day     171795 non-null  int32
#  17  outcome_event_month   171795 non-null  int32
#  18  outcome_event_year    171795 non-null  int32
#  19  outcome_event_season  171795 non-null  object
#  20  reproductive_status   171795 non-null  object
#  21  name_length           171795 non-null  int64
#  22  has_name              171795 non-null  int64
#  23  breed_type            171795 non-null  object
#  24  is_fixed              171795 non-null  int64
#  25  is_weekend            171795 non-null  int64
#  26  is_Pure_breed         171795 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int32(6), int64(5), object(13)
# memory usage: 31.5+ MB

# %%
# Identify Mix vs Pure
data['breed_type'] = data['breed'].apply(lambda x: 'Mix' if 'Mix' in x else 'Pure')

# %%
# Convert to Binary Column
data['is_fixed'] = data['reproductive_status'].apply(lambda x: 1 if x == 'Fixed' else 0)

# %%
data['is_weekend'] = data['datetime'].dt.dayofweek >= 5

# %%
data['is_weekend'] = data['is_weekend'].astype(int)

# %%
data['is_Pure_breed'] = data['breed_type'].apply(lambda x: 1 if x == 'Pure' else 0)

# %%
data_transformed = data.copy()

# %%
columns_to_drop = [
    'animal_id',        # Unique identifier, not useful for modeling
    'name',             # High cardinality, already encoded as name_length and has_name
    'datetime',         # Extracted into temporal features
    'monthyear',        # Extracted into temporal features
    'date_of_birth',    # Used to calculate age_days and age_group
    'age_upon_outcome', # Transformed into age_days and age_group
    'sex_upon_outcome', # Encoded into is_fixed
    'reproductive_status', # Encoded into is_fixed
    'breed',            # Encoded into breed_type
    'outcome_event_month',    # Redundant with outcome_season
    'outcome_event_day',      # Low predictive power and noise
    'name_length'      # Redundant with has_name
    ]

# Drop all columns in one go
data_transformed.drop(columns=columns_to_drop, inplace=True)

# %%
data_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171795 entries, 0 to 171794
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   outcome_type          171753 non-null  object
#  1   animal_type           171795 non-null  object
#  2   color                 171795 non-null  object
#  3   age_days              171780 non-null  float64
#  4   day_of_birth          171795 non-null  int32
#  5   month_of_birth        171795 non-null  int32
#  6   year_of_birth         171795 non-null  int32
#  7   outcome_event_season  171795 non-null  object
#  8   has_name              171795 non-null  int64
#  9   breed_type            171795 non-null  object
#  10  is_fixed              171795 non-null  int64
#  11  is_weekend            171795 non-null  int64
#  12  is_Pure_breed         171795 non-null  int64
# dtypes: float64(1), int32(3), int64(4), object(5)
# memory usage: 15.1+ MB

# %%
data_transformed.drop(columns=['outcome_event_year', 'outcome_subtype'], inplace=True)

# %%
data_transformed.drop(columns=['breed_type'], inplace=True)

# %%
if 'outcome_event_year' in data.columns:
    data_transformed['outcome_event_year'] = data['outcome_event_year']
else:
    print("'outcome_event_year' column not found in 'data'.")

# %%
data_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171795 entries, 0 to 171794
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   outcome_type          171753 non-null  object
#  1   animal_type           171795 non-null  object
#  2   color                 171795 non-null  object
#  3   age_days              171780 non-null  float64
#  4   day_of_birth          171795 non-null  int32
#  5   month_of_birth        171795 non-null  int32
#  6   year_of_birth         171795 non-null  int32
#  7   outcome_event_season  171795 non-null  object
#  8   has_name              171795 non-null  int64
#  9   is_fixed              171795 non-null  int64
#  10  is_weekend            171795 non-null  int64
#  11  is_Pure_breed         171795 non-null  int64
#  12  outcome_event_year    171795 non-null  int32
# dtypes: float64(1), int32(4), int64(4), object(4)
# memory usage: 14.4+ MB

# %%
data_transformed.head()
# Out:
#   outcome_type animal_type              color  age_days  day_of_birth  \
# 0     Adoption         Cat        Black/White      90.0            25
# 1    Rto-Adopt         Cat  Brown Tabby/White     730.0             2
# 2     Adoption         Dog        White/Brown     365.0            12
# 3   Euthanasia       Other               Gray     365.0            16
# 4     Adoption         Dog               Buff     120.0             8
#
#    month_of_birth  year_of_birth outcome_event_season  has_name  is_fixed  \
# 0               3           2023               Summer         1         1
# 1               5           2017               Spring         1         1
# 2               7           2017               Summer         1         1
# 3               8           2019               Summer         0         0
# 4              10           2015               Winter         1         1
#
#    is_weekend  is_Pure_breed  outcome_event_year
# 0           1              0                2023
# 1           0              0                2019
# 2           0              0                2018
# 3           1              1                2020
# 4           1              1                2016

# %%
numerical_features = data_transformed.select_dtypes(include=np.number).columns

plt.figure(figsize=(15, 10))

for i, col in enumerate(numerical_features):
    plt.subplot(3, 3, i + 1)
    sns.kdeplot(data[col], shade=True)
    plt.title(f'Density Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-54-6885989d0678>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# <ipython-input-54-6885989d0678>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# <ipython-input-54-6885989d0678>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# <ipython-input-54-6885989d0678>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# <ipython-input-54-6885989d0678>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# <ipython-input-54-6885989d0678>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# <ipython-input-54-6885989d0678>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# <ipython-input-54-6885989d0678>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# <ipython-input-54-6885989d0678>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)

# %%
outcome_distribution = data_transformed.groupby(['outcome_event_season', 'outcome_type']).size().unstack(fill_value=0)
outcome_distribution
# Out:
# outcome_type          Adoption  Died  Disposal  Euthanasia  Lost  Missing  \
# outcome_event_season
# Fall                     21568   378       211        2481     1       22
# Spring                   16057   436       250        3398     1       17
# Summer                   24796   593       273        2740     0       34
# Winter                   21096   246       133        2043     0       19
#
# outcome_type          Relocate  Return to Owner  Rto-Adopt  Stolen  Transfer
# outcome_event_season
# Fall                         9             6555        323       0     12710
# Spring                      10             6705        319       3     12158
# Summer                       6             5662        285       2     14460
# Winter                       3             6586        299       0      8865

# %%
import plotly.express as px

fig = px.bar(outcome_distribution.reset_index(),
             x='outcome_event_season',
             y=outcome_distribution.columns[1:],  # Exclude the season column
             barmode='group',  # Group for each outcome type
             title='Outcome Distribution by Season',
             labels={'value': 'Count', 'variable': 'Outcome Type', 'outcome_event_season': 'Season'},
             color_discrete_sequence=px.colors.qualitative.Set3)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2a477b8d-d5f1-48e3-8640-fdc586a41dc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a477b8d-d5f1-48e3-8640-fdc586a41dc9")) {                    Plotly.newPlot(                        "2a477b8d-d5f1-48e3-8640-fdc586a41dc9",                        [{"alignmentgroup":"True","hovertemplate":"Outcome Type=Died\u003cbr\u003eSeason=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Died","marker":{"color":"rgb(141,211,199)","pattern":{"shape":""}},"name":"Died","offsetgroup":"Died","orientation":"v","showlegend":true,"textposition":"auto","x":["Fall","Spring","Summer","Winter"],"xaxis":"x","y":[378,436,593,246],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Outcome Type=Disposal\u003cbr\u003eSeason=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Disposal","marker":{"color":"rgb(255,255,179)","pattern":{"shape":""}},"name":"Disposal","offsetgroup":"Disposal","orientation":"v","showlegend":true,"textposition":"auto","x":["Fall","Spring","Summer","Winter"],"xaxis":"x","y":[211,250,273,133],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Outcome Type=Euthanasia\u003cbr\u003eSeason=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Euthanasia","marker":{"color":"rgb(190,186,218)","pattern":{"shape":""}},"name":"Euthanasia","offsetgroup":"Euthanasia","orientation":"v","showlegend":true,"textposition":"auto","x":["Fall","Spring","Summer","Winter"],"xaxis":"x","y":[2481,3398,2740,2043],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Outcome Type=Lost\u003cbr\u003eSeason=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lost","marker":{"color":"rgb(251,128,114)","pattern":{"shape":""}},"name":"Lost","offsetgroup":"Lost","orientation":"v","showlegend":true,"textposition":"auto","x":["Fall","Spring","Summer","Winter"],"xaxis":"x","y":[1,1,0,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Outcome Type=Missing\u003cbr\u003eSeason=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Missing","marker":{"color":"rgb(128,177,211)","pattern":{"shape":""}},"name":"Missing","offsetgroup":"Missing","orientation":"v","showlegend":true,"textposition":"auto","x":["Fall","Spring","Summer","Winter"],"xaxis":"x","y":[22,17,34,19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Outcome Type=Relocate\u003cbr\u003eSeason=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Relocate","marker":{"color":"rgb(253,180,98)","pattern":{"shape":""}},"name":"Relocate","offsetgroup":"Relocate","orientation":"v","showlegend":true,"textposition":"auto","x":["Fall","Spring","Summer","Winter"],"xaxis":"x","y":[9,10,6,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Outcome Type=Return to Owner\u003cbr\u003eSeason=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Return to Owner","marker":{"color":"rgb(179,222,105)","pattern":{"shape":""}},"name":"Return to Owner","offsetgroup":"Return to Owner","orientation":"v","showlegend":true,"textposition":"auto","x":["Fall","Spring","Summer","Winter"],"xaxis":"x","y":[6555,6705,5662,6586],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Outcome Type=Rto-Adopt\u003cbr\u003eSeason=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rto-Adopt","marker":{"color":"rgb(252,205,229)","pattern":{"shape":""}},"name":"Rto-Adopt","offsetgroup":"Rto-Adopt","orientation":"v","showlegend":true,"textposition":"auto","x":["Fall","Spr ...

# %%
data_transformed["outcome_type"].value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
data_transformed["animal_type"].value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
data_transformed["breed_type"].value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
data_transformed["outcome_event_season"].value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
from sklearn.ensemble import IsolationForest

def detect_outliers(df, columns, contamination=0.05):
    """Detects outliers in specified columns using Isolation Forest.

    Args:
        df: The input DataFrame.
        columns: A list of column names to check for outliers.
        contamination: The proportion of outliers in the data set.

    Returns:
        A DataFrame with a new 'outlier' column indicating outliers (1) or inliers (0).
    """

    outlier_indices = []

    for col in columns:
      model = IsolationForest(contamination=contamination, random_state=42)
      model.fit(df[[col]])
      df[f"{col}_outlier"] = model.predict(df[[col]])
      outlier_indices.extend(df[df[f"{col}_outlier"] == -1].index.tolist())

    outlier_indices = list(set(outlier_indices))

    df['outlier'] = 0  # Initialize all rows as inliers
    df.loc[outlier_indices, 'outlier'] = 1  # Mark detected outliers

    return df
numerical_cols = ['age_days', 'day_of_birth', 'month_of_birth', 'year_of_birth', 'outcome_event_year', 'is_fixed', 'is_weekend', 'is_Pure_breed'] # Replace with your numerical column names
data_transformed = detect_outliers(data_transformed, numerical_cols)

print(data_transformed['outlier'].value_counts())
# Out:
# outlier
# 0    153946
# 1     17849
# Name: count, dtype: int64

# %%
data_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171795 entries, 0 to 171794
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   outcome_type                171753 non-null  object
#  1   animal_type                 171795 non-null  object
#  2   color                       171795 non-null  object
#  3   age_days                    171780 non-null  float64
#  4   day_of_birth                171795 non-null  int32
#  5   month_of_birth              171795 non-null  int32
#  6   year_of_birth               171795 non-null  int32
#  7   outcome_event_season        171795 non-null  object
#  8   has_name                    171795 non-null  int64
#  9   is_fixed                    171795 non-null  int64
#  10  is_weekend                  171795 non-null  int64
#  11  is_Pure_breed               171795 non-null  int64
#  12  outcome_event_year          171795 non-null  int32
#  13  age_days_outlier            171795 non-null  int64
#  14  day_of_birth_outlier        171795 non-null  int64
#  15  month_of_birth_outlier      171795 non-null  int64
#  16  year_of_birth_outlier       171795 non-null  int64
#  17  outcome_event_year_outlier  171795 non-null  int64
#  18  is_fixed_outlier            171795 non-null  int64
#  19  is_weekend_outlier          171795 non-null  int64
#  20  is_Pure_breed_outlier       171795 non-null  int64
#  21  outlier                     171795 non-null  int64
# dtypes: float64(1), int32(4), int64(13), object(4)
# memory usage: 26.2+ MB
